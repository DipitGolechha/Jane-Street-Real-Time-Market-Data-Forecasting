# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/jane-street-real-time-market-data-forecasting/responders.csv
# /kaggle/input/jane-street-real-time-market-data-forecasting/sample_submission.csv
# /kaggle/input/jane-street-real-time-market-data-forecasting/features.csv
# /kaggle/input/jane-street-real-time-market-data-forecasting/train.parquet/partition_id=4/part-0.parquet
# /kaggle/input/jane-street-real-time-market-data-forecasting/train.parquet/partition_id=5/part-0.parquet
# /kaggle/input/jane-street-real-time-market-data-forecasting/train.parquet/partition_id=6/part-0.parquet
# /kaggle/input/jane-street-real-time-market-data-forecasting/train.parquet/partition_id=3/part-0.parquet
# /kaggle/input/jane-street-real-time-market-data-forecasting/train.parquet/partition_id=1/part-0.parquet
# /kaggle/input/jane-street-real-time-market-data-forecasting/train.parquet/partition_id=8/part-0.parquet
# /kaggle/input/jane-street-real-time-market-data-forecasting/train.parquet/partition_id=2/part-0.parquet
# /kaggle/input/jane-street-real-time-market-data-forecasting/train.parquet/partition_id=0/part-0.parquet
# /kaggle/input/jane-street-real-time-market-data-forecasting/train.parquet/partition_id=7/part-0.parquet
# /kaggle/input/jane-street-real-time-market-data-forecasting/train.parquet/partition_id=9/part-0.parquet
# /kaggle/input/jane-street-real-time-market-data-forecasting/lags.parquet/date_id=0/part-0.parquet
# /kaggle/input/jane-street-real-time-market-data-forecasting/test.parquet/date_id=0/part-0.parquet
# /kaggle/input/jane-street-real-time-market-data-forecasting/kaggle_evaluation/jane_street_gateway.py
# /kaggle/input/jane-street-real-time-market-data-forecasting/kaggle_evaluation/jane_street_inference_server.py
# /kaggle/input/jane-street-real-time-market-data-forecasting/kaggle_evaluation/__init__.py
# /kaggle/input/jane-street-real-time-market-data-forecasting/kaggle_evaluation/core/templates.py
# /kaggle/input/jane-street-real-time-market-data-forecasting/kaggle_evaluation/core/base_gateway.py
# /kaggle/input/jane-street-real-time-market-data-forecasting/kaggle_evaluation/core/relay.py
# /kaggle/input/jane-street-real-time-market-data-forecasting/kaggle_evaluation/core/kaggle_evaluation.proto
# /kaggle/input/jane-street-real-time-market-data-forecasting/kaggle_evaluation/core/__init__.py
# /kaggle/input/jane-street-real-time-market-data-forecasting/kaggle_evaluation/core/generated/kaggle_evaluation_pb2.py
# /kaggle/input/jane-street-real-time-market-data-forecasting/kaggle_evaluation/core/generated/kaggle_evaluation_pb2_grpc.py
# /kaggle/input/jane-street-real-time-market-data-forecasting/kaggle_evaluation/core/generated/__init__.py

# %%
import cudf
# Load the cudf.pandas extension for pandas-like GPU acceleration
# %load_ext cudf.pandas

# %%
import pickle
import polars as pl
import pandas as pd
from cuml.linear_model import LinearRegression as cuLinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from glob import glob
import numpy as np

# Initialize variables
saved_model_path = "saved_model_lr_gpu.pkl"  # Path to save the model
model = cuLinearRegression()  # GPU-accelerated Linear Regression

for k in range(0, 10):
    # Directory containing the Parquet files
    data_path = "/kaggle/input/jane-street-real-time-market-data-forecasting/train.parquet"
    
    # Collect all Parquet file paths
    parquet_files = glob(f"{data_path}/partition_id={k}/part-0.parquet")
    
    print(f"Processing partition {k}")

    # Process each Parquet file
    final_df = pl.concat([pl.read_parquet(file) for file in parquet_files])
    
    # Print summary
    print(f"Final DataFrame shape: {final_df.shape}")
    
    # Fill NaNs with forward fill
    final_df = final_df.fill_null(strategy="forward").fill_null(strategy="backward")
    
    # List of responder columns
    responder_columns = [f"responder_{i}" for i in range(9)]
    
    # Apply the lagging for each responder column
    for responder in responder_columns:
        lagged_column_name = f"{responder}_lag_1"
        final_df = final_df.with_columns(
            pl.col(responder)
            .shift(1)
            .over(["time_id", "symbol_id"])
            .alias(lagged_column_name)
        )
    
    # Define the selected features and lagged responders
    selected_features = [
        'responder_3_lag_1', 'responder_8_lag_1', 'responder_7_lag_1', 'responder_4_lag_1', 'responder_5_lag_1',
        'responder_0_lag_1', 'responder_2_lag_1', 'responder_1_lag_1', 
        'feature_06', 'feature_60', 'feature_49', 'feature_04', 'feature_07', 
        'feature_58', 'feature_59', 'feature_47', 'feature_51', 'feature_36', 
        'feature_52', 'feature_68', 'feature_13', 'feature_02', 'feature_05', 
        'feature_41', 'feature_01', 'time_id', 'feature_54', 'feature_40', 
        'feature_03', 'feature_55', 'feature_08', 'feature_19', 'feature_48', 
        'feature_00', 'feature_71', 'feature_66', 'feature_45'
    ]
    
    # Drop all columns except the selected features and the target
    final_df = final_df.select(selected_features + ["responder_6", "date_id"])
    final_df = final_df.fill_null(0)
    
    # Convert Polars DataFrame to pandas DataFrame
    df = final_df.to_pandas()

    # Ensure these features exist in the DataFrame
    if not all(feature in df.columns for feature in selected_features):
        missing_features = [feature for feature in selected_features if feature not in df.columns]
        raise ValueError(f"Missing features in the DataFrame: {missing_features}")
    
    # Initialize storage for historical data
    historical_X = pd.DataFrame(columns=selected_features)
    historical_y = pd.Series(dtype=float)

    # Predictions for evaluation
    predictions = []
    actuals = []

    for current_date in sorted(df["date_id"].unique()):
        # Extract data for the current date_id
        current_data = df[df["date_id"] == current_date]
        X_current = current_data[selected_features].to_numpy()
        y_current = current_data["responder_6"].to_numpy()
        
        # Predict for the current rows if there's historical data
        if not historical_X.empty:
            pred = model.predict(X_current)
            predictions.extend(pred)
            actuals.extend(y_current)

        # Update the historical data and train the model
        historical_X = pd.concat([historical_X, current_data[selected_features]])
        historical_y = pd.concat([historical_y, current_data["responder_6"]])
        model.fit(historical_X.to_numpy(), historical_y.to_numpy())

        if len(actuals) == 0 or len(predictions) == 0:
            continue
    
        # Evaluate the model
        mse = mean_squared_error(actuals, predictions)
        r2 = r2_score(actuals, predictions)
    
        # Print model details and evaluation metrics
        print(f"Partition {k}, Date{current_date} - Mean Squared Error (MSE): {mse}")
        print(f"Partition {k}, Date{current_date} - R^2 Score: {r2}")
    
    # Save the model
    with open(saved_model_path, "wb") as f:
        pickle.dump(model, f)
    
    # Display predictions vs actual values
    results = pd.DataFrame({'Actual': actuals, 'Predicted': predictions})
    print(results.head())
# Out:
# /opt/conda/lib/python3.10/site-packages/cuml/internals/api_decorators.py:382: UserWarning: Starting from version 23.08, the new 'copy_X' parameter defaults to 'True', ensuring a copy of X is created after passing it to fit(), preventing any changes to the input, but with increased memory usage. This represents a change in behavior from previous versions. With `copy_X=False` a copy might still be created if necessary. Explicitly set 'copy_X' to either True or False to suppress this warning.
#   return init_func(self, *args, **filtered_kwargs)
# Processing partition 0
# Final DataFrame shape: (1944210, 92)
# Partition 0, Date1 - Mean Squared Error (MSE): 0.6865974068641663
# Partition 0, Date1 - R^2 Score: -0.040895506665343806
# Partition 0, Date2 - Mean Squared Error (MSE): 0.6777842044830322
# Partition 0, Date2 - R^2 Score: -0.04448766054959741
# Partition 0, Date3 - Mean Squared Error (MSE): 0.7724493145942688
# Partition 0, Date3 - R^2 Score: -0.03209504639460814
# Partition 0, Date4 - Mean Squared Error (MSE): 0.7002988457679749
# Partition 0, Date4 - R^2 Score: -0.02611535069144688
# Partition 0, Date5 - Mean Squared Error (MSE): 0.6982638835906982
# Partition 0, Date5 - R^2 Score: -0.015366612788089151
# Partition 0, Date6 - Mean Squared Error (MSE): 0.7041730880737305
# Partition 0, Date6 - R^2 Score: -0.012667377418040582
# Partition 0, Date7 - Mean Squared Error (MSE): 0.7096636295318604
# Partition 0, Date7 - R^2 Score: -0.009068087030298377
# Partition 0, Date8 - Mean Squared Error (MSE): 0.8561847805976868
# Partition 0, Date8 - R^2 Score: -0.012904807327055012
# Partition 0, Date9 - Mean Squared Error (MSE): 0.9014458060264587
# Partition 0, Date9 - R^2 Score: -0.013553954211077412
# Partition 0, Date10 - Mean Squared Error (MSE): 0.8905340433120728
# Partition 0, Date10 - R^2 Score: -0.011044606520605127
# Partition 0, Date11 - Mean Squared Error (MSE): 0.8806787729263306
# Partition 0, Date11 - R^2 Score: -0.010491303045219391
# Partition 0, Date12 - Mean Squared Error (MSE): 0.8651039004325867
# Partition 0, Date12 - R^2 Score: -0.009165552992056458
# Partition 0, Date13 - Mean Squared Error (MSE): 0.8625382781028748
# Partition 0, Date13 - R^2 Score: -0.006447700212434571
# Partition 0, Date14 - Mean Squared Error (MSE): 0.8477606177330017
# Partition 0, Date14 - R^2 Score: -0.005792154610585465
# Partition 0, Date15 - Mean Squared Error (MSE): 0.8254136443138123
# Partition 0, Date15 - R^2 Score: -0.004420203801934974
# Partition 0, Date16 - Mean Squared Error (MSE): 0.8251098990440369
# Partition 0, Date16 - R^2 Score: -0.004594493837538183
# Partition 0, Date17 - Mean Squared Error (MSE): 0.8168566226959229
# Partition 0, Date17 - R^2 Score: -0.0034410727250746564
# Partition 0, Date18 - Mean Squared Error (MSE): 0.8115277886390686
# Partition 0, Date18 - R^2 Score: -0.00323551585409243
# Partition 0, Date19 - Mean Squared Error (MSE): 0.7966639995574951
# Partition 0, Date19 - R^2 Score: -0.0026025893795502686
# Partition 0, Date20 - Mean Squared Error (MSE): 0.8149115443229675
# Partition 0, Date20 - R^2 Score: 0.0014846008025894974
# Partition 0, Date21 - Mean Squared Error (MSE): 0.8146331906318665
# Partition 0, Date21 - R^2 Score: 0.0019959560560196543
# Partition 0, Date22 - Mean Squared Error (MSE): 0.7970709204673767
# Partition 0, Date22 - R^2 Score: 0.0019149320590969854
# Partition 0, Date23 - Mean Squared Error (MSE): 0.7908206582069397
# Partition 0, Date23 - R^2 Score: 0.0023624381235499703
# Partition 0, Date24 - Mean Squared Error (MSE): 0.7775809168815613
# Partition 0, Date24 - R^2 Score: 0.0027306175192072235
# Partition 0, Date25 - Mean Squared Error (MSE): 0.7772082686424255
# Partition 0, Date25 - R^2 Score: 0.003315721842832353
# Partition 0, Date26 - Mean Squared Error (MSE): 0.7993173599243164
# Partition 0, Date26 - R^2 Score: 0.003481601108065724
# Partition 0, Date27 - Mean Squared Error (MSE): 0.7918834686279297
# Partition 0, Date27 - R^2 Score: 0.003661130488795572
# Partition 0, Date28 - Mean Squared Error (MSE): 0.7777812480926514
# Partition 0, Date28 - R^2 Score: 0.003678674853353936
# Partition 0, Date29 - Mean Squared Error (MSE): 0.7758376002311707
# Partition 0, Date29 - R^2 Score: 0.0046661252658273256
# Partition 0, Date30 - Mean Squared Error (MSE): 0.7619591951370239
# Partition 0, Date30 - R^2 Score: 0.004639485188498327
# Partition 0, Date31 - Mean Squared Error (MSE): 0.7673203349113464
# Partition 0, Date31 - R^2 Score: 0.0046348271375229455
# Partition 0, Date32 - Mean Squared Error (MSE): 0.7623831033706665
# Partition 0, Date32 - R^2 Score: 0.00445482986014778
# Partition 0, Date33 - Mean Squared Error (MSE): 0.7489607930183411
# Partition 0, Date33 - R^2 Score: 0.004583210730252474
# Partition 0, Date34 - Mean Squared Error (MSE): 0.7359867691993713
# Partition 0, Date34 - R^2 Score: 0.00460032135802968
# Partition 0, Date35 - Mean Squared Error (MSE): 0.7274718880653381
# Partition 0, Date35 - R^2 Score: 0.0047818591588963955
# Partition 0, Date36 - Mean Squared Error (MSE): 0.7161831259727478
# Partition 0, Date36 - R^2 Score: 0.004787847909369258
# Partition 0, Date37 - Mean Squared Error (MSE): 0.706610918045044
# Partition 0, Date37 - R^2 Score: 0.004142285500929432
# Partition 0, Date38 - Mean Squared Error (MSE): 0.6959091424942017
# Partition 0, Date38 - R^2 Score: 0.004298428051374814
# Partition 0, Date39 - Mean Squared Error (MSE): 0.6915786266326904
# Partition 0, Date39 - R^2 Score: 0.004104296279399566
# Partition 0, Date40 - Mean Squared Error (MSE): 0.6823813915252686
# Partition 0, Date40 - R^2 Score: 0.004272404992814893
# Partition 0, Date41 - Mean Squared Error (MSE): 0.6849097609519958
# Partition 0, Date41 - R^2 Score: 0.004305773894883735
# Partition 0, Date42 - Mean Squared Error (MSE): 0.679049015045166
# Partition 0, Date42 - R^2 Score: 0.004092502111572638
# Partition 0, Date43 - Mean Squared Error (MSE): 0.6811175346374512
# Partition 0, Date43 - R^2 Score: 0.003907736786685101
# Partition 0, Date44 - Mean Squared Error (MSE): 0.6879540681838989
# Partition 0, Date44 - R^2 Score: 0.004401350209167543
# Partition 0, Date45 - Mean Squared Error (MSE): 0.6860753297805786
# Partition 0, Date45 - R^2 Score: 0.004492906653186912
# Partition 0, Date46 - Mean Squared Error (MSE): 0.6855089068412781
# Partition 0, Date46 - R^2 Score: 0.004459759988660328
# Partition 0, Date47 - Mean Squared Error (MSE): 0.6807515621185303
# Partition 0, Date47 - R^2 Score: 0.004626919218518544
# Partition 0, Date48 - Mean Squared Error (MSE): 0.6835925579071045
# Partition 0, Date48 - R^2 Score: 0.004413610491296072
# Partition 0, Date49 - Mean Squared Error (MSE): 0.682509183883667
# Partition 0, Date49 - R^2 Score: 0.004505807290013486
# Partition 0, Date50 - Mean Squared Error (MSE): 0.680814266204834
# Partition 0, Date50 - R^2 Score: 0.004745874640743497
# Partition 0, Date51 - Mean Squared Error (MSE): 0.6779760718345642
# Partition 0, Date51 - R^2 Score: 0.004909983018483333
# Partition 0, Date52 - Mean Squared Error (MSE): 0.6735326647758484
# Partition 0, Date52 - R^2 Score: 0.004950287531924946
# Partition 0, Date53 - Mean Squared Error (MSE): 0.6729469299316406
# Partition 0, Date53 - R^2 Score: 0.00514833129729475
# Partition 0, Date54 - Mean Squared Error (MSE): 0.6729103922843933
# Partition 0, Date54 - R^2 Score: 0.0055873303227708115
# Partition 0, Date55 - Mean Squared Error (MSE): 0.6712220311164856
# Partition 0, Date55 - R^2 Score: 0.005870858798666334
# Partition 0, Date56 - Mean Squared Error (MSE): 0.6672736406326294
# Partition 0, Date56 - R^2 Score: 0.005929366667984715
# Partition 0, Date57 - Mean Squared Error (MSE): 0.6705538630485535
# Partition 0, Date57 - R^2 Score: 0.005778488961307282
# Partition 0, Date58 - Mean Squared Error (MSE): 0.6826003789901733
# Partition 0, Date58 - R^2 Score: -0.013132815442715051
# Partition 0, Date59 - Mean Squared Error (MSE): 0.6848598718643188
# Partition 0, Date59 - R^2 Score: -0.012600058320163532
# Partition 0, Date60 - Mean Squared Error (MSE): 0.6810286641120911
# Partition 0, Date60 - R^2 Score: -0.0123259640045148
# Partition 0, Date61 - Mean Squared Error (MSE): 0.6777913570404053
# Partition 0, Date61 - R^2 Score: -0.011839210108145481
# Partition 0, Date62 - Mean Squared Error (MSE): 0.6823667287826538
# Partition 0, Date62 - R^2 Score: -0.011266697921364033
# Partition 0, Date63 - Mean Squared Error (MSE): 0.6815205216407776
# Partition 0, Date63 - R^2 Score: -0.010916499729431983
# Partition 0, Date64 - Mean Squared Error (MSE): 0.6779454946517944
# Partition 0, Date64 - R^2 Score: -0.010457832242508625
# Partition 0, Date65 - Mean Squared Error (MSE): 0.6701162457466125
# Partition 0, Date65 - R^2 Score: -0.010242534131643666
# Partition 0, Date66 - Mean Squared Error (MSE): 0.6621705889701843
# Partition 0, Date66 - R^2 Score: -0.009958146455717243
# Partition 0, Date67 - Mean Squared Error (MSE): 0.6676401495933533
# Partition 0, Date67 - R^2 Score: -0.009650435945266711
# Partition 0, Date68 - Mean Squared Error (MSE): 0.6655797362327576
# Partition 0, Date68 - R^2 Score: -0.009313256525037339
# Partition 0, Date69 - Mean Squared Error (MSE): 0.6616714000701904
# Partition 0, Date69 - R^2 Score: -0.009004615057121912
# Partition 0, Date70 - Mean Squared Error (MSE): 0.661821722984314
# Partition 0, Date70 - R^2 Score: -0.008622508635460324
# Partition 0, Date71 - Mean Squared Error (MSE): 0.6616542935371399
# Partition 0, Date71 - R^2 Score: -0.008290691271948258
# Partition 0, Date72 - Mean Squared Error (MSE): 0.6740337014198303
# Partition 0, Date72 - R^2 Score: -0.020012872284674632
# Partition 0, Date73 - Mean Squared Error (MSE): 0.6726913452148438
# Partition 0, Date73 - R^2 Score: -0.019507377596668984
# Partition 0, Date74 - Mean Squared Error (MSE): 0.6742572784423828
# Partition 0, Date74 - R^2 Score: -0.01895073851710083
# Partition 0, Date75 - Mean Squared Error (MSE): 0.6735949516296387
# Partition 0, Date75 - R^2 Score: -0.01865152463460462
# Partition 0, Date76 - Mean Squared Error (MSE): 0.6706633567810059
# Partition 0, Date76 - R^2 Score: -0.018526172579010902
# Partition 0, Date77 - Mean Squared Error (MSE): 0.6684201955795288
# Partition 0, Date77 - R^2 Score: -0.018131229748989952
# Partition 0, Date78 - Mean Squared Error (MSE): 0.6670472025871277
# Partition 0, Date78 - R^2 Score: -0.01785164011609064
# Partition 0, Date79 - Mean Squared Error (MSE): 0.6655733585357666
# Partition 0, Date79 - R^2 Score: -0.01755633315915972
# Partition 0, Date80 - Mean Squared Error (MSE): 0.6633421182632446
# Partition 0, Date80 - R^2 Score: -0.017003225385795906
# Partition 0, Date81 - Mean Squared Error (MSE): 0.661413848400116
# Partition 0, Date81 - R^2 Score: -0.016638379975499662
# Partition 0, Date82 - Mean Squared Error (MSE): 0.6602776646614075
# Partition 0, Date82 - R^2 Score: -0.016325492885324477
# Partition 0, Date83 - Mean Squared Error (MSE): 0.6601414084434509
# Partition 0, Date83 - R^2 Score: -0.01570938798692456
# Partition 0, Date84 - Mean Squared Error (MSE): 0.6595546007156372
# Partition 0, Date84 - R^2 Score: -0.015632531603154698
# Partition 0, Date85 - Mean Squared Error (MSE): 0.6620228290557861
# Partition 0, Date85 - R^2 Score: -0.015324841140575085
# Partition 0, Date86 - Mean Squared Error (MSE): 0.6668616533279419
# Partition 0, Date86 - R^2 Score: -0.01455069179961166
# Partition 0, Date87 - Mean Squared Error (MSE): 0.6681756973266602
# Partition 0, Date87 - R^2 Score: -0.01437555727654427
# Partition 0, Date88 - Mean Squared Error (MSE): 0.6743679046630859
# Partition 0, Date88 - R^2 Score: -0.014102544572567544
# Partition 0, Date89 - Mean Squared Error (MSE): 0.6803149580955505
# Partition 0, Date89 - R^2 Score: -0.013475875339660659
# Partition 0, Date90 - Mean Squared Error (MSE): 0.6833348870277405
# Partition 0, Date90 - R^2 Score: -0.013227178279544782
# Partition 0, Date91 - Mean Squared Error (MSE): 0.6817873120307922
# Partition 0, Date91 - R^2 Score: -0.012785935883112387
# Partition 0, Date92 - Mean Squared Error (MSE): 0.6821598410606384
# Partition 0, Date92 - R^2 Score: -0.012336091361241586
# Partition 0, Date93 - Mean Squared Error (MSE): 0.6861158013343811
# Partition 0, Date93 - R^2 Score: -0.011814630500719403
# Partition 0, Date94 - Mean Squared Error (MSE): 0.6872768402099609
# Partition 0, Date94 - R^2 Score: -0.011252158619678099
# Partition 0, Date95 - Mean Squared Error (MSE): 0.6876419186592102
# Partition 0, Date95 - R^2 Score: -0.01100965248114738
# Partition 0, Date96 - Mean Squared Error (MSE): 0.6875837445259094
# Partition 0, Date96 - R^2 Score: -0.010870232115905765
# Partition 0, Date97 - Mean Squared Error (MSE): 0.6928377151489258
# Partition 0, Date97 - R^2 Score: -0.010496025395085429
# Partition 0, Date98 - Mean Squared Error (MSE): 0.6947021484375
# Partition 0, Date98 - R^2 Score: -0.010409051314563822
# Partition 0, Date99 - Mean Squared Error (MSE): 0.6935088038444519
# Partition 0, Date99 - R^2 Score: -0.010088566135181276
# Partition 0, Date100 - Mean Squared Error (MSE): 0.6894068717956543
# Partition 0, Date100 - R^2 Score: -0.01030815554557285
# Partition 0, Date101 - Mean Squared Error (MSE): 0.6855334043502808
# Partition 0, Date101 - R^2 Score: -0.010047753596581055
# Partition 0, Date102 - Mean Squared Error (MSE): 0.6841094493865967
# Partition 0, Date102 - R^2 Score: -0.009874333470182961
# Partition 0, Date103 - Mean Squared Error (MSE): 0.6829338669776917
# Partition 0, Date103 - R^2 Score: -0.009433916114592655
# Partition 0, Date104 - Mean Squared Error (MSE): 0.6806699633598328
# Partition 0, Date104 - R^2 Score: -0.009230308806409626
# Partition 0, Date105 - Mean Squared Error (MSE): 0.6810962557792664
# Partition 0, Date105 - R^2 Score: -0.008711874373170225
# Partition 0, Date106 - Mean Squared Error (MSE): 0.6810520887374878
# Partition 0, Date106 - R^2 Score: -0.008542121914565826
# Partition 0, Date107 - Mean Squared Error (MSE): 0.6823859214782715
# Partition 0, Date107 - R^2 Score: -0.008096558614430815
# Partition 0, Date108 - Mean Squared Error (MSE): 0.6802674531936646
# Partition 0, Date108 - R^2 Score: -0.007939879125101523
# Partition 0, Date109 - Mean Squared Error (MSE): 0.6784110069274902
# Partition 0, Date109 - R^2 Score: -0.0077035293357790025
# Partition 0, Date110 - Mean Squared Error (MSE): 0.6774545311927795
# Partition 0, Date110 - R^2 Score: -0.007324946151542111
# Partition 0, Date111 - Mean Squared Error (MSE): 0.6774483919143677
# Partition 0, Date111 - R^2 Score: -0.007024585438358155
# Partition 0, Date112 - Mean Squared Error (MSE): 0.6754186749458313
# Partition 0, Date112 - R^2 Score: -0.006817590723961597
# Partition 0, Date113 - Mean Squared Error (MSE): 0.6736353635787964
# Partition 0, Date113 - R^2 Score: -0.00654580371898783
# Partition 0, Date114 - Mean Squared Error (MSE): 0.6707890033721924
# Partition 0, Date114 - R^2 Score: -0.006379503459686076
# Partition 0, Date115 - Mean Squared Error (MSE): 0.6681970953941345
# Partition 0, Date115 - R^2 Score: -0.006175893178347991
# Partition 0, Date116 - Mean Squared Error (MSE): 0.6671276092529297
# Partition 0, Date116 - R^2 Score: -0.006003348824573207
# Partition 0, Date117 - Mean Squared Error (MSE): 0.6648489832878113
# Partition 0, Date117 - R^2 Score: -0.005888968486380319
# Partition 0, Date118 - Mean Squared Error (MSE): 0.6623509526252747
# Partition 0, Date118 - R^2 Score: -0.005804171411637693
# Partition 0, Date119 - Mean Squared Error (MSE): 0.660549521446228
# Partition 0, Date119 - R^2 Score: -0.005732237059115075
# Partition 0, Date120 - Mean Squared Error (MSE): 0.6622881293296814
# Partition 0, Date120 - R^2 Score: -0.005540680073660376
# Partition 0, Date121 - Mean Squared Error (MSE): 0.6643204689025879
# Partition 0, Date121 - R^2 Score: -0.005278713389755385
# Partition 0, Date122 - Mean Squared Error (MSE): 0.6661585569381714
# Partition 0, Date122 - R^2 Score: -0.005023489280107096
# Partition 0, Date123 - Mean Squared Error (MSE): 0.6652056574821472
# Partition 0, Date123 - R^2 Score: -0.00478965157750566
# Partition 0, Date124 - Mean Squared Error (MSE): 0.6662755012512207
# Partition 0, Date124 - R^2 Score: -0.004535750936301541
# Partition 0, Date125 - Mean Squared Error (MSE): 0.6658704876899719
# Partition 0, Date125 - R^2 Score: -0.004389648017393721
# Partition 0, Date126 - Mean Squared Error (MSE): 0.6687277555465698
# Partition 0, Date126 - R^2 Score: -0.004083548870450482
# Partition 0, Date127 - Mean Squared Error (MSE): 0.6685233116149902
# Partition 0, Date127 - R^2 Score: -0.0039286463970436
# Partition 0, Date128 - Mean Squared Error (MSE): 0.6665343642234802
# Partition 0, Date128 - R^2 Score: -0.003797875337860912
# Partition 0, Date129 - Mean Squared Error (MSE): 0.6767888069152832
# Partition 0, Date129 - R^2 Score: -0.004395112794726597
# Partition 0, Date130 - Mean Squared Error (MSE): 0.6834347248077393
# Partition 0, Date130 - R^2 Score: -0.004078408737564487
# Partition 0, Date131 - Mean Squared Error (MSE): 0.6884563565254211
# Partition 0, Date131 - R^2 Score: -0.0039240538256390955
# Partition 0, Date132 - Mean Squared Error (MSE): 0.6901485323905945
# Partition 0, Date132 - R^2 Score: -0.0037285094642289796
# Partition 0, Date133 - Mean Squared Error (MSE): 0.6911693215370178
# Partition 0, Date133 - R^2 Score: -0.0034735306783999498
# Partition 0, Date134 - Mean Squared Error (MSE): 0.6928408741950989
# Partition 0, Date134 - R^2 Score: -0.0031570032876404586
# Partition 0, Date135 - Mean Squared Error (MSE): 0.6935634016990662
# Partition 0, Date135 - R^2 Score: -0.0028945705817606804
# Partition 0, Date136 - Mean Squared Error (MSE): 0.6961080431938171
# Partition 0, Date136 - R^2 Score: -0.003037486063071748
# Partition 0, Date137 - Mean Squared Error (MSE): 0.7011289000511169
# Partition 0, Date137 - R^2 Score: -0.0030799380495754036
# Partition 0, Date138 - Mean Squared Error (MSE): 0.7021692991256714
# Partition 0, Date138 - R^2 Score: -0.002794003809783785
# Partition 0, Date139 - Mean Squared Error (MSE): 0.7024664282798767
# Partition 0, Date139 - R^2 Score: -0.0026254531930050007
# Partition 0, Date140 - Mean Squared Error (MSE): 0.7034440636634827
# Partition 0, Date140 - R^2 Score: -0.0026763297577736544
# Partition 0, Date141 - Mean Squared Error (MSE): 0.701599657535553
# Partition 0, Date141 - R^2 Score: -0.002584730361239629
# Partition 0, Date142 - Mean Squared Error (MSE): 0.701637327671051
# Partition 0, Date142 - R^2 Score: -0.0023930387804023123
# Partition 0, Date143 - Mean Squared Error (MSE): 0.7021631002426147
# Partition 0, Date143 - R^2 Score: -0.0022805772377427758
# Partition 0, Date144 - Mean Squared Error (MSE): 0.7083765268325806
# Partition 0, Date144 - R^2 Score: -0.0019241572709454147
# Partition 0, Date145 - Mean Squared Error (MSE): 0.7115054130554199
# Partition 0, Date145 - R^2 Score: -0.0017117720649035828
# Partition 0, Date146 - Mean Squared Error (MSE): 0.7854108810424805
# Partition 0, Date146 - R^2 Score: -0.10121072633673234
# Partition 0, Date147 - Mean Squared Error (MSE): 0.7850096821784973
# Partition 0, Date147 - R^2 Score: -0.10056974705153787
# Partition 0, Date148 - Mean Squared Error (MSE): 0.7843115925788879
# Partition 0, Date148 - R^2 Score: -0.09929646633243228
# Partition 0, Date149 - Mean Squared Error (MSE): 0.7833512425422668
# Partition 0, Date149 - R^2 Score: -0.09824479466141889
# Partition 0, Date150 - Mean Squared Error (MSE): 0.783044695854187
# Partition 0, Date150 - R^2 Score: -0.09704984000434846
# Partition 0, Date151 - Mean Squared Error (MSE): 0.7911866307258606
# Partition 0, Date151 - R^2 Score: -0.0955295465579824
# Partition 0, Date152 - Mean Squared Error (MSE): 0.7934359312057495
# Partition 0, Date152 - R^2 Score: -0.09425942595720427
# Partition 0, Date153 - Mean Squared Error (MSE): 0.8028683662414551
# Partition 0, Date153 - R^2 Score: -0.09147596395690605
# Partition 0, Date154 - Mean Squared Error (MSE): 0.8163261413574219
# Partition 0, Date154 - R^2 Score: -0.08806635848004785
# Partition 0, Date155 - Mean Squared Error (MSE): 0.8203527331352234
# Partition 0, Date155 - R^2 Score: -0.0864492496020901
# Partition 0, Date156 - Mean Squared Error (MSE): 0.820359468460083
# Partition 0, Date156 - R^2 Score: -0.08546083633165247
# Partition 0, Date157 - Mean Squared Error (MSE): 0.8215188384056091
# Partition 0, Date157 - R^2 Score: -0.08436920880628351
# Partition 0, Date158 - Mean Squared Error (MSE): 0.8208249807357788
# Partition 0, Date158 - R^2 Score: -0.08358117984631108
# Partition 0, Date159 - Mean Squared Error (MSE): 0.8197967410087585
# Partition 0, Date159 - R^2 Score: -0.0828944825578084
# Partition 0, Date160 - Mean Squared Error (MSE): 0.8192217946052551
# Partition 0, Date160 - R^2 Score: -0.08206313450220759
# Partition 0, Date161 - Mean Squared Error (MSE): 0.8177392482757568
# Partition 0, Date161 - R^2 Score: -0.08166474840204163
# Partition 0, Date162 - Mean Squared Error (MSE): 0.8171414732933044
# Partition 0, Date162 - R^2 Score: -0.08119908263466558
# Partition 0, Date163 - Mean Squared Error (MSE): 0.8161377906799316
# Partition 0, Date163 - R^2 Score: -0.08084838521985849
# Partition 0, Date164 - Mean Squared Error (MSE): 0.8166706562042236
# Partition 0, Date164 - R^2 Score: -0.07986180502950324
# Partition 0, Date165 - Mean Squared Error (MSE): 0.8175463080406189
# Partition 0, Date165 - R^2 Score: -0.07907965640299564
# Partition 0, Date166 - Mean Squared Error (MSE): 0.8176203370094299
# Partition 0, Date166 - R^2 Score: -0.07831355091520997
# Partition 0, Date167 - Mean Squared Error (MSE): 0.8181397318840027
# Partition 0, Date167 - R^2 Score: -0.07744825685480139
# Partition 0, Date168 - Mean Squared Error (MSE): 0.8172574639320374
# Partition 0, Date168 - R^2 Score: -0.07673615636154896
# Partition 0, Date169 - Mean Squared Error (MSE): 0.8171985745429993
# Partition 0, Date169 - R^2 Score: -0.07586162658703577
#      Actual  Predicted
# 0  2.337418  -0.049596
# 1  1.677068   0.050721
# 2  0.217322   0.083324
# 3  1.023567   0.038110
# 4  0.962854   0.050706
# Processing partition 1
# Final DataFrame shape: (2804247, 92)
# Partition 1, Date171 - Mean Squared Error (MSE): 1.3812888860702515
# Partition 1, Date171 - R^2 Score: -0.06704172170381151
# Partition 1, Date172 - Mean Squared Error (MSE): 1.1077502965927124
# Partition 1, Date172 - R^2 Score: -0.04823172198191705
# Partition 1, Date173 - Mean Squared Error (MSE): 1.0547231435775757
# Partition 1, Date173 - R^2 Score: -0.026921742966178552
# Partition 1, Date174 - Mean Squared Error (MSE): 1.1354222297668457
# Partition 1, Date174 - R^2 Score: -0.019874456955126574
# Partition 1, Date175 - Mean Squared Error (MSE): 1.084378957748413
# Partition 1, Date175 - R^2 Score: -0.016967409630863184
# Partition 1, Date176 - Mean Squared Error (MSE): 1.0292224884033203
# Partition 1, Date176 - R^2 Score: -0.013497306838112344
# Partition 1, Date177 - Mean Squared Error (MSE): 1.0018596649169922
# Partition 1, Date177 - R^2 Score: -0.008578748101811584
# Partition 1, Date178 - Mean Squared Error (MSE): 1.0378063917160034
# Partition 1, Date178 - R^2 Score: -0.006230659088497292
# Partition 1, Date179 - Mean Squared Error (MSE): 1.043841004371643
# Partition 1, Date179 - R^2 Score: -0.005799408081248014
# Partition 1, Date180 - Mean Squared Error (MSE): 1.064699411392212
# Partition 1, Date180 - R^2 Score: -0.0039033195185762537
# Partition 1, Date181 - Mean Squared Error (MSE): 1.056067705154419
# Partition 1, Date181 - R^2 Score: -0.0018706246749122801
# Partition 1, Date182 - Mean Squared Error (MSE): 1.0449955463409424
# Partition 1, Date182 - R^2 Score: -0.001294112862123331
# Partition 1, Date183 - Mean Squared Error (MSE): 1.0132243633270264
# Partition 1, Date183 - R^2 Score: -0.0005562832463033018
# Partition 1, Date184 - Mean Squared Error (MSE): 0.9843975305557251
# Partition 1, Date184 - R^2 Score: -0.00016066474031850575
# Partition 1, Date185 - Mean Squared Error (MSE): 0.9548619389533997
# Partition 1, Date185 - R^2 Score: -0.00032712477102347925
# Partition 1, Date186 - Mean Squared Error (MSE): 0.9300652146339417
# Partition 1, Date186 - R^2 Score: 0.0003480652498695225
# Partition 1, Date187 - Mean Squared Error (MSE): 0.9107155799865723
# Partition 1, Date187 - R^2 Score: -0.0007868512705844211
# Partition 1, Date188 - Mean Squared Error (MSE): 0.9496262073516846
# Partition 1, Date188 - R^2 Score: -0.0014517359538341879
# Partition 1, Date189 - Mean Squared Error (MSE): 0.9401895403862
# Partition 1, Date189 - R^2 Score: -0.001508698122758334
# Partition 1, Date190 - Mean Squared Error (MSE): 0.9367515444755554
# Partition 1, Date190 - R^2 Score: -0.0013210373717333912
# Partition 1, Date191 - Mean Squared Error (MSE): 0.9218614101409912
# Partition 1, Date191 - R^2 Score: -0.0009322236481237312
# Partition 1, Date192 - Mean Squared Error (MSE): 0.9041783213615417
# Partition 1, Date192 - R^2 Score: -0.0008043116897413771
# Partition 1, Date193 - Mean Squared Error (MSE): 0.8858522772789001
# Partition 1, Date193 - R^2 Score: -0.00017250803725055164
# Partition 1, Date194 - Mean Squared Error (MSE): 0.8733212947845459
# Partition 1, Date194 - R^2 Score: -0.00031745979107666855
# Partition 1, Date195 - Mean Squared Error (MSE): 0.858055830001831
# Partition 1, Date195 - R^2 Score: -0.00013912085323863899
# Partition 1, Date196 - Mean Squared Error (MSE): 0.8497886657714844
# Partition 1, Date196 - R^2 Score: 0.00026737281479372044
# Partition 1, Date197 - Mean Squared Error (MSE): 0.8404883146286011
# Partition 1, Date197 - R^2 Score: 0.0004227324024197454
# Partition 1, Date198 - Mean Squared Error (MSE): 0.8296241164207458
# Partition 1, Date198 - R^2 Score: -0.0004455525400537397
# Partition 1, Date199 - Mean Squared Error (MSE): 0.8242437839508057
# Partition 1, Date199 - R^2 Score: -0.0003797922848502999
# Partition 1, Date200 - Mean Squared Error (MSE): 0.8203223943710327
# Partition 1, Date200 - R^2 Score: -0.0003326140402750699
# Partition 1, Date201 - Mean Squared Error (MSE): 0.8109336495399475
# Partition 1, Date201 - R^2 Score: 5.10438688972048e-05
# Partition 1, Date202 - Mean Squared Error (MSE): 0.8087120056152344
# Partition 1, Date202 - R^2 Score: 0.0005426621792390396
# Partition 1, Date203 - Mean Squared Error (MSE): 0.7993189096450806
# Partition 1, Date203 - R^2 Score: 0.0007327681693770627
# Partition 1, Date204 - Mean Squared Error (MSE): 0.7946535348892212
# Partition 1, Date204 - R^2 Score: 0.0010184777093047437
# Partition 1, Date205 - Mean Squared Error (MSE): 0.8076273202896118
# Partition 1, Date205 - R^2 Score: 0.0009974549539811806
# Partition 1, Date206 - Mean Squared Error (MSE): 0.8172463178634644
# Partition 1, Date206 - R^2 Score: 0.0017114361290853086
# Partition 1, Date207 - Mean Squared Error (MSE): 0.8227291703224182
# Partition 1, Date207 - R^2 Score: 0.002229492099437347
# Partition 1, Date208 - Mean Squared Error (MSE): 0.8348592519760132
# Partition 1, Date208 - R^2 Score: 0.0017827657766842364
# Partition 1, Date209 - Mean Squared Error (MSE): 1.217054009437561
# Partition 1, Date209 - R^2 Score: -0.44429600442187644
# Partition 1, Date210 - Mean Squared Error (MSE): 1.21687912940979
# Partition 1, Date210 - R^2 Score: -0.4313188663631504
# Partition 1, Date211 - Mean Squared Error (MSE): 1.2123147249221802
# Partition 1, Date211 - R^2 Score: -0.4188673373928702
# Partition 1, Date212 - Mean Squared Error (MSE): 1.2055522203445435
# Partition 1, Date212 - R^2 Score: -0.40834464685069927
# Partition 1, Date213 - Mean Squared Error (MSE): 1.1993319988250732
# Partition 1, Date213 - R^2 Score: -0.396357375862306
# Partition 1, Date214 - Mean Squared Error (MSE): 1.1926796436309814
# Partition 1, Date214 - R^2 Score: -0.38586187359746815
# Partition 1, Date215 - Mean Squared Error (MSE): 1.198047161102295
# Partition 1, Date215 - R^2 Score: -0.37117059992969414
# Partition 1, Date216 - Mean Squared Error (MSE): 1.1915786266326904
# Partition 1, Date216 - R^2 Score: -0.361664019620906
# Partition 1, Date217 - Mean Squared Error (MSE): 1.189711093902588
# Partition 1, Date217 - R^2 Score: -0.35086891719214064
# Partition 1, Date218 - Mean Squared Error (MSE): 1.1874626874923706
# Partition 1, Date218 - R^2 Score: -0.3409585882911337
# Partition 1, Date219 - Mean Squared Error (MSE): 1.1867555379867554
# Partition 1, Date219 - R^2 Score: -0.3313741478276513
# Partition 1, Date220 - Mean Squared Error (MSE): 1.1799832582473755
# Partition 1, Date220 - R^2 Score: -0.3245050391248414
# Partition 1, Date221 - Mean Squared Error (MSE): 1.172705054283142
# Partition 1, Date221 - R^2 Score: -0.31814137804113685
# Partition 1, Date222 - Mean Squared Error (MSE): 1.1628410816192627
# Partition 1, Date222 - R^2 Score: -0.3130220460435478
# Partition 1, Date223 - Mean Squared Error (MSE): 1.151419997215271
# Partition 1, Date223 - R^2 Score: -0.3089328658305417
# Partition 1, Date224 - Mean Squared Error (MSE): 1.1509565114974976
# Partition 1, Date224 - R^2 Score: -0.3018863375814105
# Partition 1, Date225 - Mean Squared Error (MSE): 1.1496411561965942
# Partition 1, Date225 - R^2 Score: -0.2943213123096422
# Partition 1, Date226 - Mean Squared Error (MSE): 1.1421600580215454
# Partition 1, Date226 - R^2 Score: -0.2896192121265606
# Partition 1, Date227 - Mean Squared Error (MSE): 1.1353654861450195
# Partition 1, Date227 - R^2 Score: -0.28473136561239865
# Partition 1, Date228 - Mean Squared Error (MSE): 1.1420953273773193
# Partition 1, Date228 - R^2 Score: -0.295013223933831
# Partition 1, Date229 - Mean Squared Error (MSE): 1.1363248825073242
# Partition 1, Date229 - R^2 Score: -0.28984024329858515
# Partition 1, Date230 - Mean Squared Error (MSE): 1.1272000074386597
# Partition 1, Date230 - R^2 Score: -0.2865625105266203
# Partition 1, Date231 - Mean Squared Error (MSE): 1.117972493171692
# Partition 1, Date231 - R^2 Score: -0.2829798905011063
# Partition 1, Date232 - Mean Squared Error (MSE): 1.107785940170288
# Partition 1, Date232 - R^2 Score: -0.2797885252639354
# Partition 1, Date233 - Mean Squared Error (MSE): 1.1001996994018555
# Partition 1, Date233 - R^2 Score: -0.2777911379615716
# Partition 1, Date234 - Mean Squared Error (MSE): 1.0917809009552002
# Partition 1, Date234 - R^2 Score: -0.2747390677628103
# Partition 1, Date235 - Mean Squared Error (MSE): 1.085648775100708
# Partition 1, Date235 - R^2 Score: -0.2712404302036595
# Partition 1, Date236 - Mean Squared Error (MSE): 1.0781517028808594
# Partition 1, Date236 - R^2 Score: -0.26825520084468746
# Partition 1, Date237 - Mean Squared Error (MSE): 1.0690300464630127
# Partition 1, Date237 - R^2 Score: -0.2659579453097747
# Partition 1, Date238 - Mean Squared Error (MSE): 1.059532642364502
# Partition 1, Date238 - R^2 Score: -0.26353981791586123
# Partition 1, Date239 - Mean Squared Error (MSE): 1.0510090589523315
# Partition 1, Date239 - R^2 Score: -0.2609519275056289
# Partition 1, Date240 - Mean Squared Error (MSE): 1.0437015295028687
# Partition 1, Date240 - R^2 Score: -0.25811095139324136
# Partition 1, Date241 - Mean Squared Error (MSE): 1.0347658395767212
# Partition 1, Date241 - R^2 Score: -0.25616115526962746
# Partition 1, Date242 - Mean Squared Error (MSE): 1.0246011018753052
# Partition 1, Date242 - R^2 Score: -0.2548498227239471
# Partition 1, Date243 - Mean Squared Error (MSE): 1.0151067972183228
# Partition 1, Date243 - R^2 Score: -0.25341317650514394
# Partition 1, Date244 - Mean Squared Error (MSE): 1.0076229572296143
# Partition 1, Date244 - R^2 Score: -0.2516181303462921
# Partition 1, Date245 - Mean Squared Error (MSE): 1.0012580156326294
# Partition 1, Date245 - R^2 Score: -0.24909949511436702
# Partition 1, Date246 - Mean Squared Error (MSE): 0.9940642714500427
# Partition 1, Date246 - R^2 Score: -0.246983810347716
# Partition 1, Date247 - Mean Squared Error (MSE): 0.9900053143501282
# Partition 1, Date247 - R^2 Score: -0.2442604204265646
# Partition 1, Date248 - Mean Squared Error (MSE): 0.984870970249176
# Partition 1, Date248 - R^2 Score: -0.24168252451102967
# Partition 1, Date249 - Mean Squared Error (MSE): 0.9790002703666687
# Partition 1, Date249 - R^2 Score: -0.2394121451493496
# Partition 1, Date250 - Mean Squared Error (MSE): 0.9726902842521667
# Partition 1, Date250 - R^2 Score: -0.23731600524837537
# Partition 1, Date251 - Mean Squared Error (MSE): 0.9675444960594177
# Partition 1, Date251 - R^2 Score: -0.2349217820126812
# Partition 1, Date252 - Mean Squared Error (MSE): 0.9649105072021484
# Partition 1, Date252 - R^2 Score: -0.23189674031731822
# Partition 1, Date253 - Mean Squared Error (MSE): 0.9622745513916016
# Partition 1, Date253 - R^2 Score: -0.2289811761335241
# Partition 1, Date254 - Mean Squared Error (MSE): 0.9568294882774353
# Partition 1, Date254 - R^2 Score: -0.22684981966138662
# Partition 1, Date255 - Mean Squared Error (MSE): 0.9531664848327637
# Partition 1, Date255 - R^2 Score: -0.2243657721298602
# Partition 1, Date256 - Mean Squared Error (MSE): 0.951493501663208
# Partition 1, Date256 - R^2 Score: -0.2213271628414235
# Partition 1, Date257 - Mean Squared Error (MSE): 0.9481289982795715
# Partition 1, Date257 - R^2 Score: -0.218832870072732
# Partition 1, Date258 - Mean Squared Error (MSE): 0.9447224140167236
# Partition 1, Date258 - R^2 Score: -0.2164108664513198
# Partition 1, Date259 - Mean Squared Error (MSE): 0.9392712712287903
# Partition 1, Date259 - R^2 Score: -0.21473087473382257
# Partition 1, Date260 - Mean Squared Error (MSE): 0.9349782466888428
# Partition 1, Date260 - R^2 Score: -0.2125809941144048
# Partition 1, Date261 - Mean Squared Error (MSE): 0.9326471090316772
# Partition 1, Date261 - R^2 Score: -0.21016117147865998
# Partition 1, Date262 - Mean Squared Error (MSE): 0.9286995530128479
# Partition 1, Date262 - R^2 Score: -0.2085329129786906
# Partition 1, Date263 - Mean Squared Error (MSE): 0.9263067245483398
# Partition 1, Date263 - R^2 Score: -0.20636903846442967
# Partition 1, Date264 - Mean Squared Error (MSE): 0.9237013459205627
# Partition 1, Date264 - R^2 Score: -0.20414080881436814
# Partition 1, Date265 - Mean Squared Error (MSE): 0.920231819152832
# Partition 1, Date265 - R^2 Score: -0.20245964064984556
# Partition 1, Date266 - Mean Squared Error (MSE): 0.9151049852371216
# Partition 1, Date266 - R^2 Score: -0.20117543008985983
# Partition 1, Date267 - Mean Squared Error (MSE): 0.9121121168136597
# Partition 1, Date267 - R^2 Score: -0.19946440144636535
# Partition 1, Date268 - Mean Squared Error (MSE): 0.9089317917823792
# Partition 1, Date268 - R^2 Score: -0.1976605761263155
# Partition 1, Date269 - Mean Squared Error (MSE): 0.9058480858802795
# Partition 1, Date269 - R^2 Score: -0.1959032279061821
# Partition 1, Date270 - Mean Squared Error (MSE): 0.9038606286048889
# Partition 1, Date270 - R^2 Score: -0.193773421201066
# Partition 1, Date271 - Mean Squared Error (MSE): 0.905824601650238
# Partition 1, Date271 - R^2 Score: -0.19072718873987204
# Partition 1, Date272 - Mean Squared Error (MSE): 0.905957818031311
# Partition 1, Date272 - R^2 Score: -0.18835930960126301
# Partition 1, Date273 - Mean Squared Error (MSE): 0.9055727124214172
# Partition 1, Date273 - R^2 Score: -0.18596881503308138
# Partition 1, Date274 - Mean Squared Error (MSE): 0.905610203742981
# Partition 1, Date274 - R^2 Score: -0.18351151386924314
# Partition 1, Date275 - Mean Squared Error (MSE): 0.9023645520210266
# Partition 1, Date275 - R^2 Score: -0.18205406836389182
# Partition 1, Date276 - Mean Squared Error (MSE): 0.9002888202667236
# Partition 1, Date276 - R^2 Score: -0.18035471938669945
# Partition 1, Date277 - Mean Squared Error (MSE): 0.8982354402542114
# Partition 1, Date277 - R^2 Score: -0.17859984700810005
# Partition 1, Date278 - Mean Squared Error (MSE): 0.8947660326957703
# Partition 1, Date278 - R^2 Score: -0.17730051076551412
# Partition 1, Date279 - Mean Squared Error (MSE): 0.8920933604240417
# Partition 1, Date279 - R^2 Score: -0.17587016870031325
# Partition 1, Date280 - Mean Squared Error (MSE): 0.8902356624603271
# Partition 1, Date280 - R^2 Score: -0.17419842088452908
# Partition 1, Date281 - Mean Squared Error (MSE): 0.8896468281745911
# Partition 1, Date281 - R^2 Score: -0.17214075424482966
# Partition 1, Date282 - Mean Squared Error (MSE): 0.8862684965133667
# Partition 1, Date282 - R^2 Score: -0.17082648248287646
# Partition 1, Date283 - Mean Squared Error (MSE): 0.8835029006004333
# Partition 1, Date283 - R^2 Score: -0.16943685735413738
# Partition 1, Date284 - Mean Squared Error (MSE): 0.8797241449356079
# Partition 1, Date284 - R^2 Score: -0.1684210959119239
# Partition 1, Date285 - Mean Squared Error (MSE): 0.8762491941452026
# Partition 1, Date285 - R^2 Score: -0.16744999368491897
# Partition 1, Date286 - Mean Squared Error (MSE): 0.8734079599380493
# Partition 1, Date286 - R^2 Score: -0.16641706300219572
# Partition 1, Date287 - Mean Squared Error (MSE): 0.8720258474349976
# Partition 1, Date287 - R^2 Score: -0.1649583587485175
# Partition 1, Date288 - Mean Squared Error (MSE): 0.8716092705726624
# Partition 1, Date288 - R^2 Score: -0.16336437674828108
# Partition 1, Date289 - Mean Squared Error (MSE): 0.8698747158050537
# Partition 1, Date289 - R^2 Score: -0.16193543642417407
# Partition 1, Date290 - Mean Squared Error (MSE): 0.8669813871383667
# Partition 1, Date290 - R^2 Score: -0.16090679568289046
# Partition 1, Date291 - Mean Squared Error (MSE): 0.8667553067207336
# Partition 1, Date291 - R^2 Score: -0.15931852681826641
# Partition 1, Date292 - Mean Squared Error (MSE): 0.8642047643661499
# Partition 1, Date292 - R^2 Score: -0.15827118181497357
# Partition 1, Date293 - Mean Squared Error (MSE): 0.8617628216743469
# Partition 1, Date293 - R^2 Score: -0.15716569410771397
# Partition 1, Date294 - Mean Squared Error (MSE): 0.8589588403701782
# Partition 1, Date294 - R^2 Score: -0.1561630048760072
# Partition 1, Date295 - Mean Squared Error (MSE): 0.856296718120575
# Partition 1, Date295 - R^2 Score: -0.15513610328904814
# Partition 1, Date296 - Mean Squared Error (MSE): 0.8546360731124878
# Partition 1, Date296 - R^2 Score: -0.15399189319512607
# Partition 1, Date297 - Mean Squared Error (MSE): 0.8532022833824158
# Partition 1, Date297 - R^2 Score: -0.15280131853325662
# Partition 1, Date298 - Mean Squared Error (MSE): 0.8508917093276978
# Partition 1, Date298 - R^2 Score: -0.1517168196169678
# Partition 1, Date299 - Mean Squared Error (MSE): 0.8484045267105103
# Partition 1, Date299 - R^2 Score: -0.15076910855560643
# Partition 1, Date300 - Mean Squared Error (MSE): 0.8472301363945007
# Partition 1, Date300 - R^2 Score: -0.1495117669987842
# Partition 1, Date301 - Mean Squared Error (MSE): 0.8455749750137329
# Partition 1, Date301 - R^2 Score: -0.1483895731913516
# Partition 1, Date302 - Mean Squared Error (MSE): 0.844333291053772
# Partition 1, Date302 - R^2 Score: -0.14724994036702332
# Partition 1, Date303 - Mean Squared Error (MSE): 0.8416901230812073
# Partition 1, Date303 - R^2 Score: -0.14633932857240617
# Partition 1, Date304 - Mean Squared Error (MSE): 0.8413888812065125
# Partition 1, Date304 - R^2 Score: -0.1450357829436011
# Partition 1, Date305 - Mean Squared Error (MSE): 0.8400956392288208
# Partition 1, Date305 - R^2 Score: -0.14404840617689563
# Partition 1, Date306 - Mean Squared Error (MSE): 0.8383556604385376
# Partition 1, Date306 - R^2 Score: -0.14297863903925023
# Partition 1, Date307 - Mean Squared Error (MSE): 0.8381516933441162
# Partition 1, Date307 - R^2 Score: -0.14161842307059747
# Partition 1, Date308 - Mean Squared Error (MSE): 0.8377753496170044
# Partition 1, Date308 - R^2 Score: -0.1404475342648468
# Partition 1, Date309 - Mean Squared Error (MSE): 0.8362658619880676
# Partition 1, Date309 - R^2 Score: -0.13945831677552367
# Partition 1, Date310 - Mean Squared Error (MSE): 0.8326110243797302
# Partition 1, Date310 - R^2 Score: -0.13896472396399306
# Partition 1, Date311 - Mean Squared Error (MSE): 0.8310569524765015
# Partition 1, Date311 - R^2 Score: -0.1380089201514525
# Partition 1, Date312 - Mean Squared Error (MSE): 0.8308764696121216
# Partition 1, Date312 - R^2 Score: -0.13683464284589575
# Partition 1, Date313 - Mean Squared Error (MSE): 0.8348008990287781
# Partition 1, Date313 - R^2 Score: -0.13512029738621534
# Partition 1, Date314 - Mean Squared Error (MSE): 0.8347179293632507
# Partition 1, Date314 - R^2 Score: -0.13393671434877374
# Partition 1, Date315 - Mean Squared Error (MSE): 0.8357248902320862
# Partition 1, Date315 - R^2 Score: -0.13260438479098346
# Partition 1, Date316 - Mean Squared Error (MSE): 0.8409008979797363
# Partition 1, Date316 - R^2 Score: -0.13043754911428684
# Partition 1, Date317 - Mean Squared Error (MSE): 0.8486558198928833
# Partition 1, Date317 - R^2 Score: -0.1276783828995196
# Partition 1, Date318 - Mean Squared Error (MSE): 0.8511749505996704
# Partition 1, Date318 - R^2 Score: -0.12611034830507273
# Partition 1, Date319 - Mean Squared Error (MSE): 0.8510686159133911
# Partition 1, Date319 - R^2 Score: -0.12501705232926774
# Partition 1, Date320 - Mean Squared Error (MSE): 0.8494436740875244
# Partition 1, Date320 - R^2 Score: -0.12416387004864138
# Partition 1, Date321 - Mean Squared Error (MSE): 0.8525170087814331
# Partition 1, Date321 - R^2 Score: -0.1225114010503845
# Partition 1, Date322 - Mean Squared Error (MSE): 0.8581563234329224
# Partition 1, Date322 - R^2 Score: -0.12056875073511275
# Partition 1, Date323 - Mean Squared Error (MSE): 0.8584238290786743
# Partition 1, Date323 - R^2 Score: -0.11962872444153172
# Partition 1, Date324 - Mean Squared Error (MSE): 0.8575584888458252
# Partition 1, Date324 - R^2 Score: -0.11881978903874724
# Partition 1, Date325 - Mean Squared Error (MSE): 0.8580166697502136
# Partition 1, Date325 - R^2 Score: -0.11783695618539203
# Partition 1, Date326 - Mean Squared Error (MSE): 0.8610243201255798
# Partition 1, Date326 - R^2 Score: -0.11641827187216847
# Partition 1, Date327 - Mean Squared Error (MSE): 0.8619893789291382
# Partition 1, Date327 - R^2 Score: -0.11529381869217259
# Partition 1, Date328 - Mean Squared Error (MSE): 0.8632533550262451
# Partition 1, Date328 - R^2 Score: -0.11431771439062532
# Partition 1, Date329 - Mean Squared Error (MSE): 0.8671164512634277
# Partition 1, Date329 - R^2 Score: -0.11287490062781735
# Partition 1, Date330 - Mean Squared Error (MSE): 0.8731715083122253
# Partition 1, Date330 - R^2 Score: -0.11113328919442078
# Partition 1, Date331 - Mean Squared Error (MSE): 0.8745685815811157
# Partition 1, Date331 - R^2 Score: -0.11012494567004283
# Partition 1, Date332 - Mean Squared Error (MSE): 0.8794167041778564
# Partition 1, Date332 - R^2 Score: -0.10872264996289194
# Partition 1, Date333 - Mean Squared Error (MSE): 0.885612964630127
# Partition 1, Date333 - R^2 Score: -0.1072374998178629
# Partition 1, Date334 - Mean Squared Error (MSE): 0.8878489136695862
# Partition 1, Date334 - R^2 Score: -0.1060559152898013
# Partition 1, Date335 - Mean Squared Error (MSE): 0.8897383213043213
# Partition 1, Date335 - R^2 Score: -0.10500597030649828
# Partition 1, Date336 - Mean Squared Error (MSE): 0.8895512223243713
# Partition 1, Date336 - R^2 Score: -0.10420602427970005
# Partition 1, Date337 - Mean Squared Error (MSE): 0.8903724551200867
# Partition 1, Date337 - R^2 Score: -0.10347750241754938
# Partition 1, Date338 - Mean Squared Error (MSE): 0.8940480351448059
# Partition 1, Date338 - R^2 Score: -0.10225163102190238
# Partition 1, Date339 - Mean Squared Error (MSE): 0.8941709995269775
# Partition 1, Date339 - R^2 Score: -0.10154838790485132
#      Actual  Predicted
# 0  2.633653  -0.406830
# 1  0.642415   0.037827
# 2 -0.414018  -0.008011
# 3 -2.953990   0.551483
# 4 -1.413870   0.187256
# Processing partition 2
# Final DataFrame shape: (3036873, 92)
# Partition 2, Date341 - Mean Squared Error (MSE): 0.7720636129379272
# Partition 2, Date341 - R^2 Score: -0.04113450978179656
# Partition 2, Date342 - Mean Squared Error (MSE): 0.9058803915977478
# Partition 2, Date342 - R^2 Score: -0.017279495429827874
# Partition 2, Date343 - Mean Squared Error (MSE): 1.0249333381652832
# Partition 2, Date343 - R^2 Score: -0.015116048057281617
# Partition 2, Date344 - Mean Squared Error (MSE): 1.1004769802093506
# Partition 2, Date344 - R^2 Score: -0.006945663193705043
# Partition 2, Date345 - Mean Squared Error (MSE): 1.1450144052505493
# Partition 2, Date345 - R^2 Score: -0.008843093909008282
# Partition 2, Date346 - Mean Squared Error (MSE): 1.1068917512893677
# Partition 2, Date346 - R^2 Score: -0.009281842006879648
# Partition 2, Date347 - Mean Squared Error (MSE): 1.074135422706604
# Partition 2, Date347 - R^2 Score: -0.009814980548329189
# Partition 2, Date348 - Mean Squared Error (MSE): 1.0657354593276978
# Partition 2, Date348 - R^2 Score: -0.008369737977761638
# Partition 2, Date349 - Mean Squared Error (MSE): 1.1017429828643799
# Partition 2, Date349 - R^2 Score: -0.007082489127791636
# Partition 2, Date350 - Mean Squared Error (MSE): 1.1739461421966553
# Partition 2, Date350 - R^2 Score: -0.00587787792208605
# Partition 2, Date351 - Mean Squared Error (MSE): 1.137514352798462
# Partition 2, Date351 - R^2 Score: -0.005634923063735142
# Partition 2, Date352 - Mean Squared Error (MSE): 1.107859492301941
# Partition 2, Date352 - R^2 Score: -0.004732704811686084
# Partition 2, Date353 - Mean Squared Error (MSE): 1.1318085193634033
# Partition 2, Date353 - R^2 Score: -0.0045286768180581305
# Partition 2, Date354 - Mean Squared Error (MSE): 1.1361759901046753
# Partition 2, Date354 - R^2 Score: -0.003696770848514719
# Partition 2, Date355 - Mean Squared Error (MSE): 1.1470643281936646
# Partition 2, Date355 - R^2 Score: -0.003007294246364367
# Partition 2, Date356 - Mean Squared Error (MSE): 1.1823569536209106
# Partition 2, Date356 - R^2 Score: -0.0029799061296724716
# Partition 2, Date357 - Mean Squared Error (MSE): 1.1726208925247192
# Partition 2, Date357 - R^2 Score: -0.0023553144982417784
# Partition 2, Date358 - Mean Squared Error (MSE): 1.1555296182632446
# Partition 2, Date358 - R^2 Score: -0.0024022206581659766
# Partition 2, Date359 - Mean Squared Error (MSE): 1.1352720260620117
# Partition 2, Date359 - R^2 Score: -0.0022919639093841315
# Partition 2, Date360 - Mean Squared Error (MSE): 1.1222636699676514
# Partition 2, Date360 - R^2 Score: -0.001812037037237646
# Partition 2, Date361 - Mean Squared Error (MSE): 1.1061500310897827
# Partition 2, Date361 - R^2 Score: -0.0012701950124334171
# Partition 2, Date362 - Mean Squared Error (MSE): 1.0881257057189941
# Partition 2, Date362 - R^2 Score: -0.0010680262007545238
# Partition 2, Date363 - Mean Squared Error (MSE): 1.0770386457443237
# Partition 2, Date363 - R^2 Score: -0.0012837395628919612
# Partition 2, Date364 - Mean Squared Error (MSE): 1.0976788997650146
# Partition 2, Date364 - R^2 Score: -0.0005325790751953274
# Partition 2, Date365 - Mean Squared Error (MSE): 1.084149718284607
# Partition 2, Date365 - R^2 Score: -0.00029547522410222626
# Partition 2, Date366 - Mean Squared Error (MSE): 1.0777604579925537
# Partition 2, Date366 - R^2 Score: 0.00012041730529643857
# Partition 2, Date367 - Mean Squared Error (MSE): 1.0626145601272583
# Partition 2, Date367 - R^2 Score: 0.00024904214662702095
# Partition 2, Date368 - Mean Squared Error (MSE): 1.0452888011932373
# Partition 2, Date368 - R^2 Score: 0.00031275508553962883
# Partition 2, Date369 - Mean Squared Error (MSE): 1.0286288261413574
# Partition 2, Date369 - R^2 Score: 0.00039359478214218147
# Partition 2, Date370 - Mean Squared Error (MSE): 1.0140748023986816
# Partition 2, Date370 - R^2 Score: 0.0005776376077636369
# Partition 2, Date371 - Mean Squared Error (MSE): 1.0022525787353516
# Partition 2, Date371 - R^2 Score: 0.0007372382692771851
# Partition 2, Date372 - Mean Squared Error (MSE): 0.9888681769371033
# Partition 2, Date372 - R^2 Score: 0.0008278523411456851
# Partition 2, Date373 - Mean Squared Error (MSE): 0.983332097530365
# Partition 2, Date373 - R^2 Score: 0.0009044419602988185
# Partition 2, Date374 - Mean Squared Error (MSE): 0.9769043326377869
# Partition 2, Date374 - R^2 Score: 0.0010152567708843208
# Partition 2, Date375 - Mean Squared Error (MSE): 0.9836457967758179
# Partition 2, Date375 - R^2 Score: 0.0013410609344922664
# Partition 2, Date376 - Mean Squared Error (MSE): 1.0030914545059204
# Partition 2, Date376 - R^2 Score: 0.0019942747097280167
# Partition 2, Date377 - Mean Squared Error (MSE): 1.0347437858581543
# Partition 2, Date377 - R^2 Score: 0.0018427686434234758
# Partition 2, Date378 - Mean Squared Error (MSE): 1.029208779335022
# Partition 2, Date378 - R^2 Score: 0.002068499256245304
# Partition 2, Date379 - Mean Squared Error (MSE): 1.023299217224121
# Partition 2, Date379 - R^2 Score: 0.0021769201323214027
# Partition 2, Date380 - Mean Squared Error (MSE): 1.0196512937545776
# Partition 2, Date380 - R^2 Score: 0.0020322606754572536
# Partition 2, Date381 - Mean Squared Error (MSE): 1.0238736867904663
# Partition 2, Date381 - R^2 Score: 0.001990032636255634
# Partition 2, Date382 - Mean Squared Error (MSE): 1.0124554634094238
# Partition 2, Date382 - R^2 Score: 0.002083723987740038
# Partition 2, Date383 - Mean Squared Error (MSE): 1.0028630495071411
# Partition 2, Date383 - R^2 Score: 0.002210277579050568
# Partition 2, Date384 - Mean Squared Error (MSE): 0.9927288293838501
# Partition 2, Date384 - R^2 Score: 0.002194257048956816
# Partition 2, Date385 - Mean Squared Error (MSE): 0.9924651384353638
# ...
# Partition 9, Date1574 - Mean Squared Error (MSE): 0.6886828541755676
# Partition 9, Date1574 - R^2 Score: -0.006697882533494681
# Partition 9, Date1575 - Mean Squared Error (MSE): 0.683254063129425
# Partition 9, Date1575 - R^2 Score: -0.006450802712455683
# Partition 9, Date1576 - Mean Squared Error (MSE): 0.6770684719085693
# Partition 9, Date1576 - R^2 Score: -0.006299137320903592
# Partition 9, Date1577 - Mean Squared Error (MSE): 0.6752364635467529
# Partition 9, Date1577 - R^2 Score: -0.006081995746766378
# Partition 9, Date1578 - Mean Squared Error (MSE): 0.674627959728241
# Partition 9, Date1578 - R^2 Score: -0.0059867002540441305
# Partition 9, Date1579 - Mean Squared Error (MSE): 0.6727160215377808
# Partition 9, Date1579 - R^2 Score: -0.005863798770746387
# Partition 9, Date1580 - Mean Squared Error (MSE): 0.6714300513267517
# Partition 9, Date1580 - R^2 Score: -0.005770034275491831
# Partition 9, Date1581 - Mean Squared Error (MSE): 0.6730218529701233
# Partition 9, Date1581 - R^2 Score: -0.005338167665927207
# Partition 9, Date1582 - Mean Squared Error (MSE): 0.6706182360649109
# Partition 9, Date1582 - R^2 Score: -0.00523924688746269
# Partition 9, Date1583 - Mean Squared Error (MSE): 0.6683263182640076
# Partition 9, Date1583 - R^2 Score: -0.005083871935715578
# Partition 9, Date1584 - Mean Squared Error (MSE): 0.6684175729751587
# Partition 9, Date1584 - R^2 Score: -0.0051329482335438215
# Partition 9, Date1585 - Mean Squared Error (MSE): 0.6678665280342102
# Partition 9, Date1585 - R^2 Score: -0.004971838931308703
# Partition 9, Date1586 - Mean Squared Error (MSE): 0.6655585765838623
# Partition 9, Date1586 - R^2 Score: -0.004894802267847664
# Partition 9, Date1587 - Mean Squared Error (MSE): 0.6640082001686096
# Partition 9, Date1587 - R^2 Score: -0.00477073632432834
# Partition 9, Date1588 - Mean Squared Error (MSE): 0.6674782633781433
# Partition 9, Date1588 - R^2 Score: -0.004525710535555838
# Partition 9, Date1589 - Mean Squared Error (MSE): 0.6696397662162781
# Partition 9, Date1589 - R^2 Score: -0.004239236286827097
# Partition 9, Date1590 - Mean Squared Error (MSE): 0.6703757643699646
# Partition 9, Date1590 - R^2 Score: -0.004236625360896085
# Partition 9, Date1591 - Mean Squared Error (MSE): 0.6709192395210266
# Partition 9, Date1591 - R^2 Score: -0.004251862443745091
# Partition 9, Date1592 - Mean Squared Error (MSE): 0.6702842116355896
# Partition 9, Date1592 - R^2 Score: -0.0040716820438020385
# Partition 9, Date1593 - Mean Squared Error (MSE): 0.6727452278137207
# Partition 9, Date1593 - R^2 Score: -0.00394819156705295
# Partition 9, Date1594 - Mean Squared Error (MSE): 0.6820734143257141
# Partition 9, Date1594 - R^2 Score: -0.003708106313912829
# Partition 9, Date1595 - Mean Squared Error (MSE): 0.6790726184844971
# Partition 9, Date1595 - R^2 Score: -0.003682864103795147
# Partition 9, Date1596 - Mean Squared Error (MSE): 0.6817630529403687
# Partition 9, Date1596 - R^2 Score: -0.003548206209849969
# Partition 9, Date1597 - Mean Squared Error (MSE): 0.6878682971000671
# Partition 9, Date1597 - R^2 Score: -0.003313106449829961
# Partition 9, Date1598 - Mean Squared Error (MSE): 0.6902181506156921
# Partition 9, Date1598 - R^2 Score: -0.003334908673276571
# Partition 9, Date1599 - Mean Squared Error (MSE): 0.6934984922409058
# Partition 9, Date1599 - R^2 Score: -0.003227878294209896
# Partition 9, Date1600 - Mean Squared Error (MSE): 0.7083454728126526
# Partition 9, Date1600 - R^2 Score: -0.003074485396264093
# Partition 9, Date1601 - Mean Squared Error (MSE): 0.7158418893814087
# Partition 9, Date1601 - R^2 Score: -0.003123388202384225
# Partition 9, Date1602 - Mean Squared Error (MSE): 0.7172793745994568
# Partition 9, Date1602 - R^2 Score: -0.0029448337200528307
# Partition 9, Date1603 - Mean Squared Error (MSE): 0.7183807492256165
# Partition 9, Date1603 - R^2 Score: -0.0029262314597009453
# Partition 9, Date1604 - Mean Squared Error (MSE): 0.7202051281929016
# Partition 9, Date1604 - R^2 Score: -0.0028739416823992947
# Partition 9, Date1605 - Mean Squared Error (MSE): 0.7222335338592529
# Partition 9, Date1605 - R^2 Score: -0.0027446681910190396
# Partition 9, Date1606 - Mean Squared Error (MSE): 0.7239161133766174
# Partition 9, Date1606 - R^2 Score: -0.002722663686036242
# Partition 9, Date1607 - Mean Squared Error (MSE): 0.726771354675293
# Partition 9, Date1607 - R^2 Score: -0.002624711074056929
# Partition 9, Date1608 - Mean Squared Error (MSE): 0.7275775671005249
# Partition 9, Date1608 - R^2 Score: -0.0024894031692139773
# Partition 9, Date1609 - Mean Squared Error (MSE): 0.7287623286247253
# Partition 9, Date1609 - R^2 Score: -0.002469486055195036
# Partition 9, Date1610 - Mean Squared Error (MSE): 0.72800213098526
# Partition 9, Date1610 - R^2 Score: -0.0023685822221670705
# Partition 9, Date1611 - Mean Squared Error (MSE): 0.7294808626174927
# Partition 9, Date1611 - R^2 Score: -0.0024769276591265488
# Partition 9, Date1612 - Mean Squared Error (MSE): 0.7314491271972656
# Partition 9, Date1612 - R^2 Score: -0.0023577121439823934
# Partition 9, Date1613 - Mean Squared Error (MSE): 0.7311676144599915
# Partition 9, Date1613 - R^2 Score: -0.002221176924625645
# Partition 9, Date1614 - Mean Squared Error (MSE): 0.7299681305885315
# Partition 9, Date1614 - R^2 Score: -0.002240607709358189
# Partition 9, Date1615 - Mean Squared Error (MSE): 0.7285476326942444
# Partition 9, Date1615 - R^2 Score: -0.002196805915298805
# Partition 9, Date1616 - Mean Squared Error (MSE): 0.7291054129600525
# Partition 9, Date1616 - R^2 Score: -0.002163731762399257
# Partition 9, Date1617 - Mean Squared Error (MSE): 0.7280887961387634
# Partition 9, Date1617 - R^2 Score: -0.0021498994903661472
# Partition 9, Date1618 - Mean Squared Error (MSE): 0.7267889976501465
# Partition 9, Date1618 - R^2 Score: -0.0021540499277299396
# Partition 9, Date1619 - Mean Squared Error (MSE): 0.7269092798233032
# Partition 9, Date1619 - R^2 Score: -0.0021282721917470493
# Partition 9, Date1620 - Mean Squared Error (MSE): 0.7252588868141174
# Partition 9, Date1620 - R^2 Score: -0.002080534253956934
# Partition 9, Date1621 - Mean Squared Error (MSE): 0.7254946231842041
# Partition 9, Date1621 - R^2 Score: -0.002024633388156838
# Partition 9, Date1622 - Mean Squared Error (MSE): 0.7262145280838013
# Partition 9, Date1622 - R^2 Score: -0.0020553934815505936
# Partition 9, Date1623 - Mean Squared Error (MSE): 0.7267881631851196
# Partition 9, Date1623 - R^2 Score: -0.002015521332343173
# Partition 9, Date1624 - Mean Squared Error (MSE): 0.727027952671051
# Partition 9, Date1624 - R^2 Score: -0.0019622637054055314
# Partition 9, Date1625 - Mean Squared Error (MSE): 0.727188766002655
# Partition 9, Date1625 - R^2 Score: -0.0018686662322549008
# Partition 9, Date1626 - Mean Squared Error (MSE): 0.7265804409980774
# Partition 9, Date1626 - R^2 Score: -0.001812961811681113
# Partition 9, Date1627 - Mean Squared Error (MSE): 0.7274835705757141
# Partition 9, Date1627 - R^2 Score: -0.001703045101016265
# Partition 9, Date1628 - Mean Squared Error (MSE): 0.7266248464584351
# Partition 9, Date1628 - R^2 Score: -0.0017145207632216497
# Partition 9, Date1629 - Mean Squared Error (MSE): 0.7267587184906006
# Partition 9, Date1629 - R^2 Score: -0.0016792071140856457
# Partition 9, Date1630 - Mean Squared Error (MSE): 0.726085364818573
# Partition 9, Date1630 - R^2 Score: -0.0017265171874620844
# Partition 9, Date1631 - Mean Squared Error (MSE): 0.7260720729827881
# Partition 9, Date1631 - R^2 Score: -0.0016521358022234534
# Partition 9, Date1632 - Mean Squared Error (MSE): 0.7246338129043579
# Partition 9, Date1632 - R^2 Score: -0.0016540759489218626
# Partition 9, Date1633 - Mean Squared Error (MSE): 0.7224808931350708
# Partition 9, Date1633 - R^2 Score: -0.0016131177775959848
# Partition 9, Date1634 - Mean Squared Error (MSE): 0.7235901951789856
# Partition 9, Date1634 - R^2 Score: -0.001612085273739794
# Partition 9, Date1635 - Mean Squared Error (MSE): 0.7223308682441711
# Partition 9, Date1635 - R^2 Score: -0.0016022293054955838
# Partition 9, Date1636 - Mean Squared Error (MSE): 0.7224231362342834
# Partition 9, Date1636 - R^2 Score: -0.001552650355614027
# Partition 9, Date1637 - Mean Squared Error (MSE): 0.7236698269844055
# Partition 9, Date1637 - R^2 Score: -0.0014939145968666523
# Partition 9, Date1638 - Mean Squared Error (MSE): 0.7223415374755859
# Partition 9, Date1638 - R^2 Score: -0.0014871539117276011
# Partition 9, Date1639 - Mean Squared Error (MSE): 0.7201754450798035
# Partition 9, Date1639 - R^2 Score: -0.0014926515720394828
# Partition 9, Date1640 - Mean Squared Error (MSE): 0.7184529900550842
# Partition 9, Date1640 - R^2 Score: -0.0014744382753306695
# Partition 9, Date1641 - Mean Squared Error (MSE): 0.7173894047737122
# Partition 9, Date1641 - R^2 Score: -0.001500224539543682
# Partition 9, Date1642 - Mean Squared Error (MSE): 0.7160152196884155
# Partition 9, Date1642 - R^2 Score: -0.001516843954238123
# Partition 9, Date1643 - Mean Squared Error (MSE): 0.7129477858543396
# Partition 9, Date1643 - R^2 Score: -0.001501588441316981
# Partition 9, Date1644 - Mean Squared Error (MSE): 0.7105162739753723
# Partition 9, Date1644 - R^2 Score: -0.00146457832141067
# Partition 9, Date1645 - Mean Squared Error (MSE): 0.7087651491165161
# Partition 9, Date1645 - R^2 Score: -0.0014789948854270207
# Partition 9, Date1646 - Mean Squared Error (MSE): 0.7066962122917175
# Partition 9, Date1646 - R^2 Score: -0.0014782804810444805
# Partition 9, Date1647 - Mean Squared Error (MSE): 0.7038534879684448
# Partition 9, Date1647 - R^2 Score: -0.0014896138220232835
# Partition 9, Date1648 - Mean Squared Error (MSE): 0.700793981552124
# Partition 9, Date1648 - R^2 Score: -0.0015034558132722697
# Partition 9, Date1649 - Mean Squared Error (MSE): 0.6983659267425537
# Partition 9, Date1649 - R^2 Score: -0.001510949019055463
# Partition 9, Date1650 - Mean Squared Error (MSE): 0.6958373785018921
# Partition 9, Date1650 - R^2 Score: -0.0014873321556405639
# Partition 9, Date1651 - Mean Squared Error (MSE): 0.693811297416687
# Partition 9, Date1651 - R^2 Score: -0.0014959580733706623
# Partition 9, Date1652 - Mean Squared Error (MSE): 0.6914509534835815
# Partition 9, Date1652 - R^2 Score: -0.001467835416852692
# Partition 9, Date1653 - Mean Squared Error (MSE): 0.6901347637176514
# Partition 9, Date1653 - R^2 Score: -0.0014656388638296658
# Partition 9, Date1654 - Mean Squared Error (MSE): 0.6890088319778442
# Partition 9, Date1654 - R^2 Score: -0.001492205518272005
# Partition 9, Date1655 - Mean Squared Error (MSE): 0.6877340078353882
# Partition 9, Date1655 - R^2 Score: -0.001452175959204327
# Partition 9, Date1656 - Mean Squared Error (MSE): 0.6863324046134949
# Partition 9, Date1656 - R^2 Score: -0.0014409440650617888
# Partition 9, Date1657 - Mean Squared Error (MSE): 0.6850048303604126
# Partition 9, Date1657 - R^2 Score: -0.0014559279203589792
# Partition 9, Date1658 - Mean Squared Error (MSE): 0.6839213967323303
# Partition 9, Date1658 - R^2 Score: -0.0014674326110157843
# Partition 9, Date1659 - Mean Squared Error (MSE): 0.6835887432098389
# Partition 9, Date1659 - R^2 Score: -0.0014247958772846125
# Partition 9, Date1660 - Mean Squared Error (MSE): 0.6821847558021545
# Partition 9, Date1660 - R^2 Score: -0.001365332028724353
# Partition 9, Date1661 - Mean Squared Error (MSE): 0.6824090480804443
# Partition 9, Date1661 - R^2 Score: -0.0012929039665847686
# Partition 9, Date1662 - Mean Squared Error (MSE): 0.6826730370521545
# Partition 9, Date1662 - R^2 Score: -0.001275745420274088
# Partition 9, Date1663 - Mean Squared Error (MSE): 0.6830196976661682
# Partition 9, Date1663 - R^2 Score: -0.0012202825068090561
# Partition 9, Date1664 - Mean Squared Error (MSE): 0.6844707727432251
# Partition 9, Date1664 - R^2 Score: -0.001204754025295296
# Partition 9, Date1665 - Mean Squared Error (MSE): 0.684577226638794
# Partition 9, Date1665 - R^2 Score: -0.001176732344082776
# Partition 9, Date1666 - Mean Squared Error (MSE): 0.6853805184364319
# Partition 9, Date1666 - R^2 Score: -0.0011413784302576335
# Partition 9, Date1667 - Mean Squared Error (MSE): 0.6855281591415405
# Partition 9, Date1667 - R^2 Score: -0.0010818314341143331
# Partition 9, Date1668 - Mean Squared Error (MSE): 0.6860753297805786
# Partition 9, Date1668 - R^2 Score: -0.0010853159083303865
# Partition 9, Date1669 - Mean Squared Error (MSE): 0.6850792169570923
# Partition 9, Date1669 - R^2 Score: -0.0010286801636991694
# Partition 9, Date1670 - Mean Squared Error (MSE): 0.6848210692405701
# Partition 9, Date1670 - R^2 Score: -0.001006063665109247
# Partition 9, Date1671 - Mean Squared Error (MSE): 0.6838240027427673
# Partition 9, Date1671 - R^2 Score: -0.001008622440430651
# Partition 9, Date1672 - Mean Squared Error (MSE): 0.6843087077140808
# Partition 9, Date1672 - R^2 Score: -0.0009922900147980585
# Partition 9, Date1673 - Mean Squared Error (MSE): 0.6847916841506958
# Partition 9, Date1673 - R^2 Score: -0.0009161235286834213
# Partition 9, Date1674 - Mean Squared Error (MSE): 0.6845507025718689
# Partition 9, Date1674 - R^2 Score: -0.0008651325299984247
# Partition 9, Date1675 - Mean Squared Error (MSE): 0.6833748817443848
# Partition 9, Date1675 - R^2 Score: -0.0008454255343139927
# Partition 9, Date1676 - Mean Squared Error (MSE): 0.6824965476989746
# Partition 9, Date1676 - R^2 Score: -0.0008363393853054735
# Partition 9, Date1677 - Mean Squared Error (MSE): 0.6807140111923218
# Partition 9, Date1677 - R^2 Score: -0.0008217954048748144
# Partition 9, Date1678 - Mean Squared Error (MSE): 0.6799523234367371
# Partition 9, Date1678 - R^2 Score: -0.0007660577586501294
# Partition 9, Date1679 - Mean Squared Error (MSE): 0.6794132590293884
# Partition 9, Date1679 - R^2 Score: -0.0007511866818645796
# Partition 9, Date1680 - Mean Squared Error (MSE): 0.6781745553016663
# Partition 9, Date1680 - R^2 Score: -0.0007248514173858744
# Partition 9, Date1681 - Mean Squared Error (MSE): 0.6777461171150208
# Partition 9, Date1681 - R^2 Score: -0.000694010661028921
# Partition 9, Date1682 - Mean Squared Error (MSE): 0.6773859262466431
# Partition 9, Date1682 - R^2 Score: -0.0006279193021281326
# Partition 9, Date1683 - Mean Squared Error (MSE): 0.6763224005699158
# Partition 9, Date1683 - R^2 Score: -0.0006048112410521611
# Partition 9, Date1684 - Mean Squared Error (MSE): 0.6751432418823242
# Partition 9, Date1684 - R^2 Score: -0.0005922536938605116
# Partition 9, Date1685 - Mean Squared Error (MSE): 0.6758980751037598
# Partition 9, Date1685 - R^2 Score: -0.0005807181515662396
# Partition 9, Date1686 - Mean Squared Error (MSE): 0.6745564937591553
# Partition 9, Date1686 - R^2 Score: -0.0005578529700087653
# Partition 9, Date1687 - Mean Squared Error (MSE): 0.6731322407722473
# Partition 9, Date1687 - R^2 Score: -0.0005237023859487877
# Partition 9, Date1688 - Mean Squared Error (MSE): 0.6711964011192322
# Partition 9, Date1688 - R^2 Score: -0.0005007291512648671
# Partition 9, Date1689 - Mean Squared Error (MSE): 0.6699304580688477
# Partition 9, Date1689 - R^2 Score: -0.0004975828225428636
# Partition 9, Date1690 - Mean Squared Error (MSE): 0.6686424612998962
# Partition 9, Date1690 - R^2 Score: -0.0005098671810446209
# Partition 9, Date1691 - Mean Squared Error (MSE): 0.667340874671936
# Partition 9, Date1691 - R^2 Score: -0.0004892521882815526
# Partition 9, Date1692 - Mean Squared Error (MSE): 0.6668110489845276
# Partition 9, Date1692 - R^2 Score: -0.0004542686046611344
# Partition 9, Date1693 - Mean Squared Error (MSE): 0.6660360097885132
# Partition 9, Date1693 - R^2 Score: -0.00044460925253853034
# Partition 9, Date1694 - Mean Squared Error (MSE): 0.6646819114685059
# Partition 9, Date1694 - R^2 Score: -0.0004144134276631295
# Partition 9, Date1695 - Mean Squared Error (MSE): 0.6646624803543091
# Partition 9, Date1695 - R^2 Score: -0.0004030519125692855
# Partition 9, Date1696 - Mean Squared Error (MSE): 0.6645402908325195
# Partition 9, Date1696 - R^2 Score: -0.0004035447679040516
# Partition 9, Date1697 - Mean Squared Error (MSE): 0.6650654077529907
# Partition 9, Date1697 - R^2 Score: -0.0004227574732227346
# Partition 9, Date1698 - Mean Squared Error (MSE): 0.6645870208740234
# Partition 9, Date1698 - R^2 Score: -0.00038538171496882434
#      Actual  Predicted
# 0 -0.653524  -0.069160
# 1  0.207838   0.030154
# 2 -0.440971  -0.083813
# 3  0.799452   0.083978
# 4 -0.656046   0.243439
